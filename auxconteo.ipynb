# %%
import pandas as pd

# %%
df_2004 = pd.read_csv(r'C:\Users\franc\Documents\OneDrive\Documentos\GitHub\Recod_Historico\Set_Alma\data_Set_Riec_2004\result\Db_2004_2009.csv')

# %%
len(df_2004)
# Out:
# 130252

# %%
df_2010 = pd.read_csv(r'C:\Users\franc\Documents\OneDrive\Documentos\GitHub\Recod_Historico\Set_Alma\data_Set_Riec_2010\result\db_2010.csv')

# %%
len(df_2010)
# Out:
# 29864

# %%
df_2013 = pd.read_csv(r'C:\Users\franc\Documents\OneDrive\Documentos\GitHub\Recod_Historico\Set_Alma\data_Set_Riec_2011-2013\result\db_2011_13.csv')
# Out:
# C:\Users\franc\AppData\Local\Temp\ipykernel_4168\3917046812.py:1: DtypeWarning: Columns (95,98,100,101,102,103,104,105,106,107,108,109,110,111,112) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2013 = pd.read_csv(r'C:\Users\franc\Documents\OneDrive\Documentos\GitHub\Recod_Historico\Set_Alma\data_Set_Riec_2011-2013\result\db_2011_13.csv')

# %%
len(df_2013)
# Out:
# 94547

# %%
df_2013['FolioId'].value_counts()
# Out:
# FolioId
#  -9370          595
#  -9351          456
#  -9320          367
#  -9460          314
#  -9381          297
#                ...
# 98829-9880.0      1
# 98916-9310.0      1
# 98927-9734.0      1
# 98934-9040.0      1
# 74088-9381        1
# Name: count, Length: 81378, dtype: int64

# %%
df_grupo_merge = pd.read_csv(r'C:\Users\franc\Documents\OneDrive\Documentos\GitHub\Recod_Historico\Set_Alma\Merge_2010_2013\result\EI_2004_2013(Grupo).csv')
# Out:
# C:\Users\franc\AppData\Local\Temp\ipykernel_4168\3892259228.py:1: DtypeWarning: Columns (58) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_grupo_merge = pd.read_csv(r'C:\Users\franc\Documents\OneDrive\Documentos\GitHub\Recod_Historico\Set_Alma\Merge_2010_2013\result\EI_2004_2013(Grupo).csv')

# %%
len(df_grupo_merge)
# Out:
# 254663

# %%
df_sust_merge = pd.read_csv(r'C:\Users\franc\Documents\OneDrive\Documentos\GitHub\Recod_Historico\Set_Alma\Merge_2010_2013\result\EI_2004_2013(Sustancias).csv')
# Out:
# C:\Users\franc\AppData\Local\Temp\ipykernel_4168\3993644294.py:1: DtypeWarning: Columns (96,99,100,102,103,104,105,107,108,109,110,111,112,113,114) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sust_merge = pd.read_csv(r'C:\Users\franc\Documents\OneDrive\Documentos\GitHub\Recod_Historico\Set_Alma\Merge_2010_2013\result\EI_2004_2013(Sustancias).csv')

# %%
len(df_sust_merge)
# Out:
# 254663

# %%
avgpo_ilegales = pd.read_csv(r'C:\Users\franc\Documents\OneDrive\Documentos\GitHub\Recod_Historico\Set_Alma\Merge_2010_2013\result\EI_AlgunaVez_2004_2013(GrupoIlegales).csv')
len(avgpo_ilegales)
# Out:
# C:\Users\franc\AppData\Local\Temp\ipykernel_4168\1460993734.py:1: DtypeWarning: Columns (52) have mixed types. Specify dtype option on import or set low_memory=False.
#   avgpo_ilegales = pd.read_csv(r'C:\Users\franc\Documents\OneDrive\Documentos\GitHub\Recod_Historico\Set_Alma\Merge_2010_2013\result\EI_AlgunaVez_2004_2013(GrupoIlegales).csv')
# 207418

# %%
avgpo_legales = pd.read_csv(r'C:\Users\franc\Documents\OneDrive\Documentos\GitHub\Recod_Historico\Set_Alma\Act_Sust_Historic\results\hist-SUST-UM-SI.csv')
len(avgpo_legales)
# Out:
# C:\Users\franc\AppData\Local\Temp\ipykernel_4168\783084286.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   avgpo_legales = pd.read_csv(r'C:\Users\franc\Documents\OneDrive\Documentos\GitHub\Recod_Historico\Set_Alma\Act_Sust_Historic\results\hist-SUST-UM-SI.csv')
# 316803

# %%
aux = pd.read_csv(r'C:\Users\franc\Documents\OneDrive\Documentos\GitHub\Recod_Historico\thsd_SUST-UM-SLI.csv')
len(aux)
# Out:
# 100773

# %%
aux['FechaRegistro'].value_counts()
# Out:
# FechaRegistro
# 2021-04-13 00:00:00.000    3
# 2021-04-09 00:00:00.000    2
# 2021-03-22 00:00:00.000    2
# 2022-07-11 00:00:00.000    2
# 2021-03-08 00:00:00.000    2
#                           ..
# 2021-01-18 20:25:01.070    1
# 2021-01-19 00:39:44.147    1
# 2021-01-19 09:16:29.020    1
# 2021-01-19 09:28:22.807    1
# 2021-01-15 22:38:58.983    1
# Name: count, Length: 144334, dtype: int64
